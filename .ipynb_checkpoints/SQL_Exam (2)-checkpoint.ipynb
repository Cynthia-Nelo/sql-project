# %% [markdown]
# # SQL Exam

# %% [markdown]
# ## Instructions to students
#
# This challenge is designed to determine how much you have learned so far and will test your knowledge on SQL.
#
# The answers for this challenge should be selected on Athena for each corresponding multiple-choice question. The questions are included in this notebook and are numbered according to the Athena questions. The options for each question have also been included.
#
# Do not add or remove cells in this notebook. Do not edit or remove the `%%sql` comment as it is required to run each cell.
#
# **_Good luck!_**

# %% [markdown]
# ## Honour code
#
# I, Cynthia Nwankwo Amakeze, confirm – by submitting this document – that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code

# %%
## The TMDb database

In this supplementary exam, you will be exploring [The Movie Database](https://www.themoviedb.org/) – an online movie and TV show database that houses some of the most popular movies and TV shows at your fingertips. The TMDb database supports 39 official languages used in over 180 countries daily and dates back all the way to 2008. 


<img src="https://github.com/Explore-AI/Pictures/blob/master/sql_tmdb.jpg?raw=true" width=80%/>


Below is an Entity Relationship Diagram (ERD) of the TMDb database:

<img src="https://github.com/Explore-AI/Pictures/blob/master/TMDB_ER_diagram.png?raw=true" width=70%/>

As can be seen from the ERD, the TMDb database consists of `12 tables` containing information about movies, cast, genre, and so much more.  

Let's get started!
# Out:
#   Cell In[4], line 3
#     In this supplementary exam, you will be exploring [The Movie Database](https://www.themoviedb.org/) – an online movie and TV show database that houses some of the most popular movies and TV shows at your fingertips. The TMDb database supports 39 official languages used in over 180 countries daily and dates back all the way to 2008.
#                                                                                                         ^
# SyntaxError: invalid character '–' (U+2013)

# %% [markdown]
# ## Loading the database
#
# Before you begin, you need to prepare your SQL environment.  You can do this by loading the magic command `%load_ext sql`.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %% [markdown]
# Next, go ahead and load your database. To do this, you will need to ensure you have downloaded the `TMDB.db` sqlite file from Athena and have stored it in a known location.

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql sqlite:///TMDB.db
# Out:
# 'Connected: @TMDB.db'

# %% [markdown]
# If the above line didn't throw out any errors, then you should be good to go. Good luck with the exam!

# %% [markdown]
# ## Questions on SQL
#
# Use the given cell below each question to execute your SQL queries to find the correct input from the options provided. Your solution should match one of the multiple-choice questions on Athena.

# %% [markdown]
# ### Question 1
#
# Who won the Oscar for “Actor in a Leading Role” in  2015?
#
# (Hint: The winner is indicated as '1.0'.)
#
# **Options:**
#
#   - Micheal Fassbender
#   - Natalie Portman
#   - Leonardo DiCaprio
#   - Eddie Redmayne

# %%
# %%sql
#
# SELECT name
# FROM oscars
# WHERE award = 'Actor in a Leading Role'
# AND winner = 1.0
# AND year = 2015;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('Leonardo DiCaprio',)]

# %% [markdown]
# ### Question 2
#
# What query will produce the ten oldest movies in the database?
#
# **Options:**
#
#  - SELECT TOP(10) * FROM movies WHERE release_date ORDER BY release_date ASC
#
#  - SELECT  * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
#
#  - SELECT * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date DESC LIMIT 10
#
#  -  SELECT * FROM movies WHERE release_date IS NULL ORDER BY release_date DESC LIMIT 10

# %%
# %%sql
#
# SELECT *
# FROM movies
# WHERE release_date IS NOT NULL
# ORDER BY release_date DESC
# LIMIT 10;

# %% [markdown]
# ### Question 3
#
# How many unique awards are there in the Oscars table?
#
# **Options:**
#  - 141
#  - 53
#  - 80
#  - 114

# %%
# %%sql
#
# SELECT count(DISTINCT award) AS distinct_award
# FROM oscars;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(114,)]

# %% [markdown]
# ### Question 4
#
# How many movies are there that contain the word “Spider” within their title?
#
# **Options:**
#  - 0
#  - 5
#  - 1
#  - 9

# %%
# %%sql
#
# SELECT count(DISTINCT title) as distinct_titles
# FROM movies
# WHERE title
# LIKE '%spider%';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(9,)]

# %% [markdown]
# ### Question 5
#
# How many movies are there that are both in the "Thriller" genre and contain the word “love” anywhere in the keywords?
#
#
# **Options:**
#  - 48
#  - 38
#  - 14
#  - 1

# %%
# %%sql
#
# SELECT count(Distinct M.title) AS title_count
# FROM genres AS G
# RIGHT JOIN genremap AS GM
# ON G.genre_id = GM.genre_id
# RIGHT JOIN movies AS M
# ON GM.movie_id = M.movie_id
# RIGHT JOIN keywordmap AS KM
# ON M.movie_id = KM.movie_id
# RIGHT JOIN keywords AS K
# ON KM.keyword_id = k.keyword_id
# WHERE genre_name = 'Thriller'
# AND keyword_name
# LIKE '%love%';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(48,)]

# %% [markdown]
# ### Question 6
#
# How many movies are there that were released between 1 August 2006 ('2006-08-01') and 1 October 2009 ('2009-10-01') that have a popularity score of more than 40 and a budget of less than 50 000 000?
#
#
# **Options:**
#
#  - 29
#  - 23
#  - 28
#  - 35

# %%
# %%sql
#
# SELECT count(title)
# FROM movies
# WHERE release_date BETWEEN '2006-08-01' AND '2009-10-01'
# AND popularity > 40
# AND budget < 50000000;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(29,)]

# %% [markdown]
# ### Question 7
#
# How many unique characters has "Vin Diesel" played so far in the database?
#
# **Options:**
#  - 24
#  - 19
#  - 18
#  - 16

# %%
# %%sql
#
# SELECT COUNT(characters)
# FROM casts AS C
# INNER JOIN actors AS A
# ON C.actor_id = A.actor_id
# WHERE A.actor_name = 'Vin Diesel';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(19,)]

# %% [markdown]
# ### Question 8
#
# What are the genres of the movie “The Royal Tenenbaums”?
#
#
# **Options:**
#  - Action, Romance
#  - Drama, Comedy
#  - Crime, Thriller
#  - Drama, Romance

# %%
# %%sql
#
# SELECT genre_name
# FROM genres AS G
# LEFT JOIN genremap AS GM
# ON G.genre_id = GM.genre_id
# LEFT JOIN movies AS M
# ON GM.movie_id = M.movie_id
# WHERE M.title = 'The Royal Tenenbaums';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('Drama',), ('Comedy',)]

# %% [markdown]
# ### Question 9
#
# What are the three production companies that have the highest movie popularity score on average, as recorded within the database?
#
#
# **Options:**
#
#  - MCL Films S.A., Turner Pictures, and George Stevens Productions
#  - The Donners' Company, Bulletproof Cupid, and Kinberg Genre
#  - Bulletproof Cupid, The Donners' Company, and MCL Films S.A
#  - B.Sting Entertainment, Illumination Pictures, and Aztec Musique

# %%
# %%sql
#
# SELECT production_company_name,
#        popularity,
#        AVG(popularity) OVER (PARTITION BY production_company_name)
#  AS avg_pop
# FROM productioncompanies AS PC
# LEFT JOIN productioncompanymap AS PCM
# ON PC.production_company_id = PCM.production_company_id
# JOIN movies AS M
# ON PCM.movie_id = M.movie_id
# ORDER BY avg_pop DESC
# LIMIT 3;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [("The Donners' Company", 514.569956, 514.569956),
#  ('Bulletproof Cupid', 481.098624, 481.098624),
#  ('Kinberg Genre', 139.272042, 326.92099900000005)]

# %% [markdown]
# ### Question 10
#
# How many female actors (i.e. gender = 1) have a name that starts with the letter "N"?
#
#
# **Options:**
#
#  - 0
#  - 355
#  - 7335
#  - 1949

# %%
# %%sql
#
# SELECT count(gender)
# FROM actors
# WHERE actor_name
# LIKE 'N%'
# AND gender = 1;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(355,)]

# %% [markdown]
# ### Question 11
#
# Which genre has, on average, the lowest movie popularity score?
#
#
# **Options:**
#
#  - Science Fiction
#  - Animation
#  - Documentary
#  - Foreign

# %%
# %%sql
#
# SELECT genre_name,
#        popularity,
#        AVG(popularity) OVER (PARTITION BY genre_name)
# AS avg_pop
# FROM genres AS G
# LEFT JOIN genremap AS GM
# ON G.genre_id = GM.genre_id
# JOIN movies AS M
# ON GM.movie_id = M.movie_id
# ORDER BY avg_pop
# LIMIT 1;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('Foreign', 2.787375, 0.686786794117647)]

# %% [markdown]
# ### Question 12
#
# Which award category has the highest number of actor nominations (actors can be male or female)? (Hint: `Oscars.name` contains both actors' names and film names.)
#
# **Options:**
#
# - Special Achievement Award
# - Actor in a Supporting Role
# - Actress in a Supporting Role
# - Best Picture

# %%
# %%sql
#
# SELECT name,
#        award,
# count(award) OVER (PARTITION BY YEAR)
# AS disct_count
# FROM oscars
# ORDER BY disct_count DESC;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('James Cagney', 'Actor', 186),
#  ('Ronald Colman', 'Actor', 186),
#  ('Gary Cooper', 'Actor', 186),
#  ('Walter Pidgeon', 'Actor', 186),
#  ('Monty Woolley', 'Actor', 186),
#  ('William Bendix', 'Actor in a Supporting Role', 186),
#  ('Van Heflin', 'Actor in a Supporting Role', 186),
#  ('Walter Huston', 'Actor in a Supporting Role', 186),
#  ('Frank Morgan', 'Actor in a Supporting Role', 186),
#  ('Henry Travers', 'Actor in a Supporting Role', 186),
#  ('Bette Davis', 'Actress', 186),
#  ('Greer Garson', 'Actress', 186),
#  ('Katharine Hepburn', 'Actress', 186),
#  ('Rosalind Russell', 'Actress', 186),
#  ('Teresa Wright', 'Actress', 186),
#  ('Gladys Cooper', 'Actress in a Supporting Role', 186),
#  ('Agnes Moorehead', 'Actress in a Supporting Role', 186),
#  ('Susan Peters', 'Actress in a Supporting Role', 186),
#  ('Dame May Whitty', 'Actress in a Supporting Role', 186),
#  ('Teresa Wright', 'Actress in a Supporting Role', 186),
#  ('George Washington Slept Here ', 'Art Direction (Black and White)', 186),
#  ('The Magnificent Ambersons ', 'Art Direction (Black and White)', 186),
#  ('The Pride of the Yankees ', 'Art Direction (Black and White)', 186),
#  ('Random Harvest ', 'Art Direction (Black and White)', 186),
#  ('The Shanghai Gesture ', 'Art Direction (Black and White)', 186),
#  ('Silver Queen ', 'Art Direction (Black and White)', 186),
#  ('The Spoilers ', 'Art Direction (Black and White)', 186),
#  ('Take a Letter, Darling ', 'Art Direction (Black and White)', 186),
#  ('The Talk of the Town ', 'Art Direction (Black and White)', 186),
#  ('This above All ', 'Art Direction (Black and White)', 186),
#  ('Arabian Nights ', 'Art Direction (Color)', 186),
#  ('Captains of the Clouds ', 'Art Direction (Color)', 186),
#  ('Jungle Book ', 'Art Direction (Color)', 186),
#  ('My Gal Sal ', 'Art Direction (Color)', 186),
#  ('Reap the Wild Wind ', 'Art Direction (Color)', 186),
#  ('Kings Row ', 'Cinematography (Black and White)', 186),
#  ('The Magnificent Ambersons ', 'Cinematography (Black and White)', 186),
#  ('Mrs. Miniver ', 'Cinematography (Black and White)', 186),
#  ('Moontide ', 'Cinematography (Black and White)', 186),
#  ('The Pied Piper ', 'Cinematography (Black and White)', 186),
#  ('The Pride of the Yankees ', 'Cinematography (Black and White)', 186),
#  ('Take a Letter, Darling ', 'Cinematography (Black and White)', 186),
#  ('The Talk of the Town ', 'Cinematography (Black and White)', 186),
#  ('Ten Gentlemen from West Point ', 'Cinematography (Black and White)', 186),
#  ('This above All ', 'Cinematography (Black and White)', 186),
#  ('Arabian Nights ', 'Cinematography (Color)', 186),
#  ('The Black Swan ', 'Cinematography (Color)', 186),
#  ('Captains of the Clouds ', 'Cinematography (Color)', 186),
#  ('Jungle Book ', 'Cinematography (Color)', 186),
#  ('Reap the Wild Wind ', 'Cinematography (Color)', 186),
#  ('To the Shores of Tripoli ', 'Cinematography (Color)', 186),
#  ('Kings Row ', 'Directing', 186),
#  ('Mrs. Miniver ', 'Directing', 186),
#  ('Random Harvest ', 'Directing', 186),
#  ('Wake Island ', 'Directing', 186),
#  ('Yankee Doodle Dandy ', 'Directing', 186),
#  ('Africa, Prelude to Victory ', 'Documentary', 186),
#  ('The Battle of Midway ', 'Documentary', 186),
#  ('Combat Report ', 'Documentary', 186),
#  ('Conquer by the Clock ', 'Documentary', 186),
#  ('The Grain That Built a Hemisphere ', 'Documentary', 186),
#  ('Henry Browne, Farmer ', 'Documentary', 186),
#  ('High over the Borders ', 'Documentary', 186),
#  ('High Stakes in the East ', 'Documentary', 186),
#  ('Inside Fighting China ', 'Documentary', 186),
#  ("It's Everybody's War ", 'Documentary', 186),
#  ('Kokoda Front Line! ', 'Documentary', 186),
#  ('Listen to Britain ', 'Documentary', 186),
#  ('Little Belgium ', 'Documentary', 186),
#  ('Little Isles of Freedom ', 'Documentary', 186),
#  ('Mr. Blabbermouth! ', 'Documentary', 186),
#  ('Mr. Gardenia Jones ', 'Documentary', 186),
#  ('Moscow Strikes Back ', 'Documentary', 186),
#  ('The New Spirit ', 'Documentary', 186),
#  ('Prelude to War ', 'Documentary', 186),
#  ('The Price of Victory ', 'Documentary', 186),
#  ('A Ship Is Born ', 'Documentary', 186),
#  ('Twenty-One Miles ', 'Documentary', 186),
#  ('We Refuse to Die ', 'Documentary', 186),
#  ('White Eagle ', 'Documentary', 186),
#  ('Winning Your Wings ', 'Documentary', 186),
#  ('Mrs. Miniver ', 'Film Editing', 186),
#  ('The Pride of the Yankees ', 'Film Editing', 186),
#  ('The Talk of the Town ', 'Film Editing', 186),
#  ('This above All ', 'Film Editing', 186),
#  ('Yankee Doodle Dandy ', 'Film Editing', 186),
#  ('Arabian Nights ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Bambi ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Black Swan ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Corsican Brothers ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Flying Tigers ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Gold Rush ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('I Married a Witch ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Joan of Paris ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Jungle Book ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Klondike Fury ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Now, Voyager ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Pride of the Yankees ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Random Harvest ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Shanghai Gesture ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Silver Queen ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Take a Letter, Darling ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('The Talk of the Town ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('To Be or Not to Be ', 'Music (Music Score of a Dramatic or Comedy Picture)', 186),
#  ('Flying with Music ', 'Music (Scoring of a Musical Picture)', 186),
#  ('For Me and My Gal ', 'Music (Scoring of a Musical Picture)', 186),
#  ('Holiday Inn ', 'Music (Scoring of a Musical Picture)', 186),
#  ('It Started with Eve ', 'Music (Scoring of a Musical Picture)', 186),
#  ('Johnny Doughboy ', 'Music (Scoring of a Musical Picture)', 186),
#  ('My Gal Sal ', 'Music (Scoring of a Musical Picture)', 186),
#  ('Yankee Doodle Dandy ', 'Music (Scoring of a Musical Picture)', 186),
#  ('You Were Never Lovelier ', 'Music (Scoring of a Musical Picture)', 186),
#  ('"""Always In My Heart"" from Always in My Heart"', 'Music (Song)', 186),
#  ('"""Dearly Beloved"" from You Were Never Lovelier"', 'Music (Song)', 186),
#  ('"""How About You?"" from Babes on Broadway"', 'Music (Song)', 186),
#  ('"""It Seems I Heard That Song Before"" from Youth on Parade"', 'Music (Song)', 186),
#  ('"""I\'ve Got A Gal In Kalamazoo"" from Orchestra Wives"', 'Music (Song)', 186),
#  ('"""Love Is A Song"" from Bambi"', 'Music (Song)', 186),
#  ('"""Pennies For Peppino"" from Flying with Music"', 'Music (Song)', 186),
#  ('"""Pig Foot Pete"" from Hellzapoppin\'"', 'Music (Song)', 186),
#  ('"""There\'s A Breeze On Lake Louise"" from The Mayor of 44th Street"', 'Music (Song)', 186),
#  ('"""White Christmas"" from Holiday Inn"', 'Music (Song)', 186),
#  ('The Invaders ', 'Outstanding Motion Picture', 186),
#  ('Kings Row ', 'Outstanding Motion Picture', 186),
#  ('The Magnificent Ambersons ', 'Outstanding Motion Picture', 186),
#  ('Mrs. Miniver ', 'Outstanding Motion Picture', 186),
#  ('The Pied Piper ', 'Outstanding Motion Picture', 186),
#  ('The Pride of the Yankees ', 'Outstanding Motion Picture', 186),
#  ('Random Harvest ', 'Outstanding Motion Picture', 186),
#  ('The Talk of the Town ', 'Outstanding Motion Picture', 186),
#  ('Wake Island ', 'Outstanding Motion Picture', 186),
#  ('Yankee Doodle Dandy ', 'Outstanding Motion Picture', 186),
#  ("All Out for 'V' ", 'Short Subject (Cartoon)', 186),
#  ('Blitz Wolf ', 'Short Subject (Cartoon)', 186),
#  ("Der Fuehrer's Face ", 'Short Subject (Cartoon)', 186),
#  ('Juke Box Jamboree ', 'Short Subject (Cartoon)', 186),
#  ('Pigs in a Polka ', 'Short Subject (Cartoon)', 186),
#  ('Tulips Shall Grow ', 'Short Subject (Cartoon)', 186),
#  ('Desert Wonderland ', 'Short Subject (One Reel)', 186),
#  ('Marines in the Making ', 'Short Subject (One Reel)', 186),
#  ('Speaking of Animals and Their Families ', 'Short Subject (One Reel)', 186),
#  ('United States Marine Band ', 'Short Subject (One Reel)', 186),
#  ('Beyond the Line of Duty ', 'Short Subject (Two Reel)', 186),
#  ("Don't Talk ", 'Short Subject (Two Reel)', 186),
#  ('Private Smith of the U.S.A. ', 'Short Subject (Two Reel)', 186),
#  ('Arabian Nights ', 'Sound Recording', 186),
#  ('Bambi ', 'Sound Recording', 186),
#  ('Flying Tigers ', 'Sound Recording', 186),
#  ('Friendly Enemies ', 'Sound Recording', 186),
#  ('The Gold Rush ', 'Sound Recording', 186),
#  ('Mrs. Miniver ', 'Sound Recording', 186),
#  ('Once upon a Honeymoon ', 'Sound Recording', 186),
#  ('The Pride of the Yankees ', 'Sound Recording', 186),
#  ('Road to Morocco ', 'Sound Recording', 186),
#  ('This above All ', 'Sound Recording', 186),
#  ('Yankee Doodle Dandy ', 'Sound Recording', 186),
#  ('You Were Never Lovelier ', 'Sound Recording', 186),
#  ('The Black Swan ', 'Special Effects', 186),
#  ('Desperate Journey ', 'Special Effects', 186),
#  ('Flying Tigers ', 'Special Effects', 186),
#  ('Invisible Agent ', 'Special Effects', 186),
#  ('Jungle Book ', 'Special Effects', 186),
#  ('Mrs. Miniver ', 'Special Effects', 186),
#  ('The Navy Comes Through ', 'Special Effects', 186),
#  ('One of Our Aircraft Is Missing ', 'Special Effects', 186),
#  ('The Pride of the Yankees ', 'Special Effects', 186),
#  ('Reap the Wild Wind ', 'Special Effects', 186),
#  ('Holiday Inn ', 'Writing (Original Motion Picture Story)', 186),
#  ('The Invaders ', 'Writing (Original Motion Picture Story)', 186),
#  ('The Pride of the Yankees ', 'Writing (Original Motion Picture Story)', 186),
#  ('The Talk of the Town ', 'Writing (Original Motion Picture Story)', 186),
#  ('Yankee Doodle Dandy ', 'Writing (Original Motion Picture Story)', 186),
#  ('One of Our Aircraft Is Missing ', 'Writing (Original Screenplay)', 186),
#  ('Road to Morocco ', 'Writing (Original Screenplay)', 186),
#  ('Wake Island ', 'Writing (Original Screenplay)', 186),
#  ('The War against Mrs. Hadley ', 'Writing (Original Screenplay)', 186),
#  ('Woman of the Year ', 'Writing (Original Screenplay)', 186),
#  ('The Invaders ', 'Writing (Screenplay)', 186),
#  ('Mrs. Miniver ', 'Writing (Screenplay)', 186),
#  ('The Pride of the Yankees ', 'Writing (Screenplay)', 186),
#  ('Random Harvest ', 'Writing (Screenplay)', 186),
#  ('The Talk of the Town ', 'Writing (Screenplay)', 186),
#  ('Charles Boyer', 'Special Award', 186),
#  ('Noel Coward', 'Special Award', 186),
#  ('Metro-Goldwyn-Mayer', 'Special Award', 186),
#  ('Sidney Franklin', 'Irving G. Thalberg Memorial Award', 186),
#  ('Gary Cooper', 'Actor', 183),
#  ('Cary Grant', 'Actor', 183),
#  ('Walter Huston', 'Actor', 183),
#  ('Robert Montgomery', 'Actor', 183),
#  ('Orson Welles', 'Actor', 183),
#  ('Walter Brennan', 'Actor in a Supporting Role', 183),
#  ('Charles Coburn', 'Actor in a Supporting Role', 183),
#  ('Donald Crisp', 'Actor in a Supporting Role', 183),
#  ('James Gleason', 'Actor in a Supporting Role', 183),
#  ('Sydney Greenstreet', 'Actor in a Supporting Role', 183),
#  ('Bette Davis', 'Actress', 183),
#  ('Olivia de Havilland', 'Actress', 183),
#  ('Joan Fontaine', 'Actress', 183),
#  ('Greer Garson', 'Actress', 183),
#  ('Barbara Stanwyck', 'Actress', 183),
#  ('Sara Allgood', 'Actress in a Supporting Role', 183),
#  ('Mary Astor', 'Actress in a Supporting Role', 183),
#  ('Patricia Collinge', 'Actress in a Supporting Role', 183),
#  ('Teresa Wright', 'Actress in a Supporting Role', 183),
#  ('Margaret Wycherly', 'Actress in a Supporting Role', 183),
#  ('Citizen Kane ', 'Art Direction (Black and White)', 183),
#  ('The Flame of New Orleans ', 'Art Direction (Black and White)', 183),
#  ('Hold Back the Dawn ', 'Art Direction (Black and White)', 183),
#  ('How Green Was My Valley ', 'Art Direction (Black and White)', 183),
#  ('Ladies in Retirement ', 'Art Direction (Black and White)', 183),
#  ('The Little Foxes ', 'Art Direction (Black and White)', 183),
#  ('Sergeant York ', 'Art Direction (Black and White)', 183),
#  ('Sis Hopkins', 'Art Direction (Black and White)', 183),
#  ('The Son of Monte Cristo ', 'Art Direction (Black and White)', 183),
#  ('Sundown ', 'Art Direction (Black and White)', 183),
#  ('That Hamilton Woman ', 'Art Direction (Black and White)', 183),
#  ('When Ladies Meet ', 'Art Direction (Black and White)', 183),
#  ('Blood and Sand ', 'Art Direction (Color)', 183),
#  ('Blossoms in the Dust ', 'Art Direction (Color)', 183),
#  ('Louisiana Purchase ', 'Art Direction (Color)', 183),
#  ('The Chocolate Soldier ', 'Cinematography (Black and White)', 183),
#  ('Citizen Kane ', 'Cinematography (Black and White)', 183),
#  ('Dr. Jekyll and Mr. Hyde ', 'Cinematography (Black and White)', 183),
#  ('Here Comes Mr. Jordan ', 'Cinematography (Black and White)', 183),
#  ('Hold Back the Dawn ', 'Cinematography (Black and White)', 183),
#  ('How Green Was My Valley ', 'Cinematography (Black and White)', 183),
#  ('Sergeant York ', 'Cinematography (Black and White)', 183),
#  ('Sun Valley Serenade ', 'Cinematography (Black and White)', 183),
#  ('Sundown ', 'Cinematography (Black and White)', 183),
#  ('That Hamilton Woman ', 'Cinematography (Black and White)', 183),
#  ('Aloma of the South Seas ', 'Cinematography (Color)', 183),
#  ('Billy the Kid ', 'Cinematography (Color)', 183),
#  ('Blood and Sand ', 'Cinematography (Color)', 183),
#  ('Blossoms in the Dust ', 'Cinematography (Color)', 183),
#  ('Dive Bomber ', 'Cinematography (Color)', 183),
#  ('Louisiana Purchase ', 'Cinematography (Color)', 183),
#  ('Citizen Kane ', 'Directing', 183),
#  ('Here Comes Mr. Jordan ', 'Directing', 183),
#  ('How Green Was My Valley ', 'Directing', 183),
#  ('The Little Foxes ', 'Directing', 183),
#  ('Sergeant York ', 'Directing', 183),
#  ('Adventure in the Bronx ', 'Documentary (Short Subject)', 183),
#  ('Bomber ', 'Documentary (Short Subject)', 183),
#  ('Christmas under Fire ', 'Documentary (Short Subject)', 183),
#  ("Churchill's Island ", 'Documentary (Short Subject)', 183),
#  ('Letter from Home ', 'Documentary (Short Subject)', 183),
#  ('Life of a Thoroughbred ', 'Documentary (Short Subject)', 183),
#  ('Norway in Revolt ', 'Documentary (Short Subject)', 183),
#  ('A Place to Live ', 'Documentary (Short Subject)', 183),
#  ('Russian Soil ', 'Documentary (Short Subject)', 183),
#  ('Soldiers of the Sky ', 'Documentary (Short Subject)', 183),
#  ('War Clouds in the Pacific ', 'Documentary (Short Subject)', 183),
#  ('Citizen Kane ', 'Film Editing', 183),
#  ('Dr. Jekyll and Mr. Hyde ', 'Film Editing', 183),
#  ('How Green Was My Valley ', 'Film Editing', 183),
#  ('The Little Foxes ', 'Film Editing', 183),
#  ('Sergeant York ', 'Film Editing', 183),
#  ('All That Money Can Buy ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Back Street ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Ball of Fire ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Cheers for Miss Bishop ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Citizen Kane ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Dr. Jekyll and Mr. Hyde ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Hold Back the Dawn ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('How Green Was My Valley ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('King of the Zombies ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Ladies in Retirement ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('The Little Foxes ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Lydia ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Mercy Island ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Sergeant York ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('So Ends Our Night ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Sundown ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Suspicion ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('Tanks a Million ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('That Uncertain Feeling ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('This Woman Is Mine ', 'Music (Music Score of a Dramatic Picture)', 183),
#  ('All-American Co-Ed ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Birth of the Blues ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Buck Privates ', 'Music (Scoring of a Musical Picture)', 183),
#  ('The Chocolate Soldier ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Dumbo ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Ice-Capades ', 'Music (Scoring of a Musical Picture)', 183),
#  ('The Strawberry Blonde ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Sun Valley Serenade ', 'Music (Scoring of a Musical Picture)', 183),
#  ('Sunny ', 'Music (Scoring of a Musical Picture)', 183),
#  ("You'll Never Get Rich ", 'Music (Scoring of a Musical Picture)', 183),
#  ('"""Baby Mine"" from Dumbo"', 'Music (Song)', 183),
#  ('"""Be Honest With Me"" from Ridin\' on a Rainbow"', 'Music (Song)', 183),
#  ('"""Blues In The Night"" from Blues in the Night"', 'Music (Song)', 183),
#  ('"""Boogie Woogie Bugle Boy Of Company B"" from Buck Privates"', 'Music (Song)', 183),
#  ('"""Chattanooga Choo Choo"" from Sun Valley Serenade"', 'Music (Song)', 183),
#  ('"""Dolores"" from Las Vegas Nights"', 'Music (Song)', 183),
#  ('"""The Last Time I Saw Paris"" from Lady Be Good"', 'Music (Song)', 183),
#  ('"""Out Of The Silence"" from All-American Co-Ed"', 'Music (Song)', 183),
#  ('"""Since I Kissed My Baby Goodbye"" from You\'ll Never Get Rich"', 'Music (Song)', 183),
#  ('Blossoms in the Dust ', 'Outstanding Motion Picture', 183),
#  ('Citizen Kane ', 'Outstanding Motion Picture', 183),
#  ('Here Comes Mr. Jordan ', 'Outstanding Motion Picture', 183),
#  ('Hold Back the Dawn ', 'Outstanding Motion Picture', 183),
#  ('How Green Was My Valley ', 'Outstanding Motion Picture', 183),
#  ('The Little Foxes ', 'Outstanding Motion Picture', 183),
#  ('The Maltese Falcon ', 'Outstanding Motion Picture', 183),
#  ('One Foot in Heaven ', 'Outstanding Motion Picture', 183),
#  ('Sergeant York ', 'Outstanding Motion Picture', 183),
#  ('Suspicion ', 'Outstanding Motion Picture', 183),
#  ('Boogie Woogie Bugle Boy of Company B ', 'Short Subject (Cartoon)', 183),
#  ("Hiawatha's Rabbit Hunt ", 'Short Subject (Cartoon)', 183),
#  ('How War Came ', 'Short Subject (Cartoon)', 183),
#  ('Lend a Paw ', 'Short Subject (Cartoon)', 183),
#  ('The Night before Christmas ', 'Short Subject (Cartoon)', 183),
#  ('Rhapsody in Rivets ', 'Short Subject (Cartoon)', 183),
#  ('Rhythm in the Ranks ', 'Short Subject (Cartoon)', 183),
#  ('The Rookie Bear ', 'Short Subject (Cartoon)', 183),
#  ('Superman ', 'Short Subject (Cartoon)', 183),
#  ('Truant Officer Donald ', 'Short Subject (Cartoon)', 183),
#  ('Army Champions ', 'Short Subject (One Reel)', 183),
#  ('Beauty and the Beach ', 'Short Subject (One Reel)', 183),
#  ('Down on the Farm ', 'Short Subject (One Reel)', 183),
#  ('Forty Boys and a Song ', 'Short Subject (One Reel)', 183),
#  ('Kings of the Turf ', 'Short Subject (One Reel)', 183),
#  ('Of Pups and Puzzles ', 'Short Subject (One Reel)', 183),
#  ('Sagebrush and Silver ', 'Short Subject (One Reel)', 183),
#  ('Alive in the Deep ', 'Short Subject (Two Reel)', 183),
#  ('Forbidden Passage ', 'Short Subject (Two Reel)', 183),
#  ('The Gay Parisian ', 'Short Subject (Two Reel)', 183),
#  ('Main Street on the March! ', 'Short Subject (Two Reel)', 183),
#  ('The Tanks Are Coming ', 'Short Subject (Two Reel)', 183),
#  ('Appointment for Love ', 'Sound Recording', 183),
#  ('Ball of Fire ', 'Sound Recording', 183),
#  ('The Chocolate Soldier ', 'Sound Recording', 183),
#  ('Citizen Kane ', 'Sound Recording', 183),
#  ('The Devil Pays Off ', 'Sound Recording', 183),
#  ('How Green Was My Valley ', 'Sound Recording', 183),
#  ('The Men in Her Life ', 'Sound Recording', 183),
#  ('Sergeant York ', 'Sound Recording', 183),
#  ('Skylark ', 'Sound Recording', 183),
#  ('That Hamilton Woman ', 'Sound Recording', 183),
#  ('Topper Returns ', 'Sound Recording', 183),
#  ('Aloma of the South Seas ', 'Special Effects', 183),
#  ('Dive Bomber ', 'Special Effects', 183),
#  ('Flight Command ', 'Special Effects', 183),
#  ('I Wanted Wings ', 'Special Effects', 183),
#  ('The Invisible Woman ', 'Special Effects', 183),
#  ('The Sea Wolf ', 'Special Effects', 183),
#  ('That Hamilton Woman ', 'Special Effects', 183),
#  ('Topper Returns ', 'Special Effects', 183),
#  ('A Yank in the R.A.F. ', 'Special Effects', 183),
#  ('Citizen Kane ', 'Writing (Original Screenplay)', 183),
#  ('The Devil and Miss Jones ', 'Writing (Original Screenplay)', 183),
#  ('Sergeant York ', 'Writing (Original Screenplay)', 183),
#  ('Tall, Dark and Handsome ', 'Writing (Original Screenplay)', 183),
#  ('Tom, Dick and Harry ', 'Writing (Original Screenplay)', 183),
#  ('Ball of Fire ', 'Writing (Original Story)', 183),
#  ('Here Comes Mr. Jordan ', 'Writing (Original Story)', 183),
#  ('The Lady Eve ', 'Writing (Original Story)', 183),
#  ('Meet John Doe ', 'Writing (Original Story)', 183),
#  ('Night Train ', 'Writing (Original Story)', 183),
#  ('Here Comes Mr. Jordan ', 'Writing (Screenplay)', 183),
#  ('Hold Back the Dawn ', 'Writing (Screenplay)', 183),
#  ('How Green Was My Valley ', 'Writing (Screenplay)', 183),
#  ('The Little Foxes ', 'Writing (Screenplay)', 183),
#  ('The Maltese Falcon ', 'Writing (Screenplay)', 183),
#  ('Rey Scott', 'Special Award', 183),
#  ('The British Ministry of Information', 'Special Award', 183),
#  ('Leopold Stokowski and Associates', 'Special Award', 183),
#  ('Walt Disney, William Garity, John N. A. Hawkins and the RCA Manufacturing Company', 'Special Award', 183),
#  ('Walt Disney', 'Irving G. Thalberg Memorial Award', 183),
#  ('Humphrey Bogart', 'Actor', 182),
#  ('Gary Cooper', 'Actor', 182),
#  ('Paul Lukas', 'Actor', 182),
#  ('Walter Pidgeon', 'Actor', 182),
#  ('Mickey Rooney', 'Actor', 182),
#  ('Charles Bickford', 'Actor in a Supporting Role', 182),
#  ('Charles Coburn', 'Actor in a Supporting Role', 182),
#  ('J. Carrol Naish', 'Actor in a Supporting Role', 182),
#  ('Claude Rains', 'Actor in a Supporting Role', 182),
#  ('Akim Tamiroff', 'Actor in a Supporting Role', 182),
#  ('Jean Arthur', 'Actress', 182),
#  ('Ingrid Bergman', 'Actress', 182),
#  ('Joan Fontaine', 'Actress', 182),
#  ('Greer Garson', 'Actress', 182),
#  ('Jennifer Jones', 'Actress', 182),
#  ('Gladys Cooper', 'Actress in a Supporting Role', 182),
#  ('Paulette Goddard', 'Actress in a Supporting Role', 182),
#  ('Katina Paxinou', 'Actress in a Supporting Role', 182),
#  ('Anne Revere', 'Actress in a Supporting Role', 182),
#  ('Lucile Watson', 'Actress in a Supporting Role', 182),
#  ('Five Graves to Cairo ', 'Art Direction (Black and White)', 182),
#  ('Flight for Freedom ', 'Art Direction (Black and White)', 182),
#  ('Madame Curie ', 'Art Direction (Black and White)', 182),
#  ('Mission to Moscow ', 'Art Direction (Black and White)', 182),
#  ('The North Star ', 'Art Direction (Black and White)', 182),
#  ('The Song of Bernadette ', 'Art Direction (Black and White)', 182),
#  ('For Whom the Bell Tolls ', 'Art Direction (Color)', 182),
#  ("The Gang's All Here ", 'Art Direction (Color)', 182),
#  ('Phantom of the Opera ', 'Art Direction (Color)', 182),
#  ('This Is the Army ', 'Art Direction (Color)', 182),
#  ('Thousands Cheer ', 'Art Direction (Color)', 182),
#  ('Air Force ', 'Cinematography (Black and White)', 182),
#  ('Casablanca ', 'Cinematography (Black and White)', 182),
#  ('Corvette K-225 ', 'Cinematography (Black and White)', 182),
#  ('Five Graves to Cairo ', 'Cinematography (Black and White)', 182),
#  ('The Human Comedy ', 'Cinematography (Black and White)', 182),
#  ('Madame Curie ', 'Cinematography (Black and White)', 182),
#  ('The North Star ', 'Cinematography (Black and White)', 182),
#  ('Sahara ', 'Cinematography (Black and White)', 182),
#  ('So Proudly We Hail! ', 'Cinematography (Black and White)', 182),
#  ('The Song of Bernadette ', 'Cinematography (Black and White)', 182),
#  ('For Whom the Bell Tolls ', 'Cinematography (Color)', 182),
#  ('Heaven Can Wait ', 'Cinematography (Color)', 182),
#  ('Hello, Frisco, Hello ', 'Cinematography (Color)', 182),
#  ('Lassie Come Home ', 'Cinematography (Color)', 182),
#  ('Phantom of the Opera ', 'Cinematography (Color)', 182),
#  ('Thousands Cheer ', 'Cinematography (Color)', 182),
#  ('Casablanca ', 'Directing', 182),
#  ('Heaven Can Wait ', 'Directing', 182),
#  ('The Human Comedy ', 'Directing', 182),
#  ('The More the Merrier ', 'Directing', 182),
#  ('The Song of Bernadette ', 'Directing', 182),
#  ('Baptism of Fire ', 'Documentary (Feature)', 182),
#  ('The Battle of Russia ', 'Documentary (Feature)', 182),
#  ('Desert Victory ', 'Documentary (Feature)', 182),
#  ('For God and Country ', 'Documentary (Feature)', 182),
#  ('Report from the Aleutians ', 'Documentary (Feature)', 182),
#  ('Silent Village ', 'Documentary (Feature)', 182),
#  ('War Department Report ', 'Documentary (Feature)', 182),
#  ("We've Come a Long, Long Way ", 'Documentary (Feature)', 182),
#  ('Bismarck Convoy Smashed ', 'Documentary (Short Subject)', 182),
#  ('Children of Mars ', 'Documentary (Short Subject)', 182),
#  ('Day of Battle ', 'Documentary (Short Subject)', 182),
#  ('December 7th ', 'Documentary (Short Subject)', 182),
#  ('The Dutch Tradition ', 'Documentary (Short Subject)', 182),
#  ('Kill or Be Killed ', 'Documentary (Short Subject)', 182),
#  ('The Labor Front ', 'Documentary (Short Subject)', 182),
#  ('Land of My Mother ', 'Documentary (Short Subject)', 182),
#  ('Letter from Livingston ', 'Documentary (Short Subject)', 182),
#  ('Life Line ', 'Documentary (Short Subject)', 182),
#  ('Plan for Destruction ', 'Documentary (Short Subject)', 182),
#  ('The Rear Gunner ', 'Documentary (Short Subject)', 182),
#  ('Servant of a Nation ', 'Documentary (Short Subject)', 182),
#  ('Swedes in America ', 'Documentary (Short Subject)', 182),
#  ('Task Force ', 'Documentary (Short Subject)', 182),
#  ('To the People of the United States ', 'Documentary (Short Subject)', 182),
#  ('Tomorrow We Fly ', 'Documentary (Short Subject)', 182),
#  ('The Voice That Thrilled the World ', 'Documentary (Short Subject)', 182),
#  ('Water--Friend or Enemy ', 'Documentary (Short Subject)', 182),
#  ('Wings Up ', 'Documentary (Short Subject)', 182),
#  ('Youth in Crisis ', 'Documentary (Short Subject)', 182),
#  ('Air Force ', 'Film Editing', 182),
#  ('Casablanca ', 'Film Editing', 182),
#  ('Five Graves to Cairo ', 'Film Editing', 182),
#  ('For Whom the Bell Tolls ', 'Film Editing', 182),
#  ('The Song of Bernadette ', 'Film Editing', 182),
#  ('The Amazing Mrs. Holliday ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Casablanca ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Commandos Strike at Dawn ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('The Fallen Sparrow ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('For Whom the Bell Tolls ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Hangmen Also Die ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Hi Diddle Diddle ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('In Old Oklahoma ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Johnny Come Lately ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('The Kansan ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Lady of Burlesque ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Madame Curie ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('The Moon and Sixpence ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('The North Star ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('The Song of Bernadette ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Victory through Air Power ', 'Music (Music Score of a Dramatic or Comedy Picture)', 182),
#  ('Coney Island ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Hit Parade of 1943 ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Phantom of the Opera ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Saludos Amigos ', 'Music (Scoring of a Musical Picture)', 182),
#  ("The Sky's the Limit ", 'Music (Scoring of a Musical Picture)', 182),
#  ('Something to Shout About ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Stage Door Canteen ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Star Spangled Rhythm ', 'Music (Scoring of a Musical Picture)', 182),
#  ('This Is the Army ', 'Music (Scoring of a Musical Picture)', 182),
#  ('Thousands Cheer ', 'Music (Scoring of a Musical Picture)', 182),
#  ('"""A Change Of Heart"" from Hit Parade of 1943"', 'Music (Song)', 182),
#  ('"""Happiness Is A Thing Called Joe"" from Cabin in the Sky"', 'Music (Song)', 182),
#  ('"""My Shining Hour"" from The Sky\'s the Limit"', 'Music (Song)', 182),
#  ('"""Saludos Amigos"" from Saludos Amigos"', 'Music (Song)', 182),
#  ('"""Say A Pray\'r For The Boys Over There"" from Hers to Hold"', 'Music (Song)', 182),
#  ('"""That Old Black Magic"" from Star Spangled Rhythm"', 'Music (Song)', 182),
#  ('"""They\'re Either Too Young Or Too Old"" from Thank Your Lucky Stars"', 'Music (Song)', 182),
#  ('"""We Mustn\'t Say Goodbye"" from Stage Door Canteen"', 'Music (Song)', 182),
#  ('"""You\'d Be So Nice To Come Home To"" from Something to Shout About"', 'Music (Song)', 182),
#  ('"""You\'ll Never Know"" from Hello, Frisco, Hello"', 'Music (Song)', 182),
#  ('Casablanca ', 'Outstanding Motion Picture', 182),
#  ('For Whom the Bell Tolls ', 'Outstanding Motion Picture', 182),
#  ('Heaven Can Wait ', 'Outstanding Motion Picture', 182),
#  ('The Human Comedy ', 'Outstanding Motion Picture', 182),
#  ('In Which We Serve ', 'Outstanding Motion Picture', 182),
#  ('Madame Curie ', 'Outstanding Motion Picture', 182),
#  ('The More the Merrier ', 'Outstanding Motion Picture', 182),
#  ('The Ox-Bow Incident ', 'Outstanding Motion Picture', 182),
#  ('The Song of Bernadette ', 'Outstanding Motion Picture', 182),
#  ('Watch on the Rhine ', 'Outstanding Motion Picture', 182),
#  ('The Dizzy Acrobat ', 'Short Subject (Cartoon)', 182),
#  ('The 500 Hats of Bartholomew Cubbins ', 'Short Subject (Cartoon)', 182),
#  ('Greetings Bait! ', 'Short Subject (Cartoon)', 182),
#  ('Imagination ', 'Short Subject (Cartoon)', 182),
#  ('Reason and Emotion ', 'Short Subject (Cartoon)', 182),
#  ('Yankee Doodle Mouse ', 'Short Subject (Cartoon)', 182),
#  ('Amphibious Fighters ', 'Short Subject (One Reel)', 182),
#  ('Cavalcade of Dance with Veloz and Yolanda ', 'Short Subject (One Reel)', 182),
#  ('Champions Carry On ', 'Short Subject (One Reel)', 182),
#  ('Hollywood in Uniform ', 'Short Subject (One Reel)', 182),
#  ('Seeing Hands ', 'Short Subject (One Reel)', 182),
#  ('Heavenly Music ', 'Short Subject (Two Reel)', 182),
#  ('Letter to a Hero ', 'Short Subject (Two Reel)', 182),
#  ('Mardi Gras ', 'Short Subject (Two Reel)', 182),
#  ('Women at War ', 'Short Subject (Two Reel)', 182),
#  ('Hangmen Also Die ', 'Sound Recording', 182),
#  ('In Old Oklahoma ', 'Sound Recording', 182),
#  ('Madame Curie ', 'Sound Recording', 182),
#  ('The North Star ', 'Sound Recording', 182),
#  ('Phantom of the Opera ', 'Sound Recording', 182),
#  ('Riding High ', 'Sound Recording', 182),
#  ('Sahara ', 'Sound Recording', 182),
#  ('Saludos Amigos ', 'Sound Recording', 182),
#  ('So This Is Washington ', 'Sound Recording', 182),
#  ('The Song of Bernadette ', 'Sound Recording', 182),
#  ('This Is the Army ', 'Sound Recording', 182),
#  ('This Land Is Mine ', 'Sound Recording', 182),
#  ('Air Force ', 'Special Effects', 182),
#  ('Bombardier ', 'Special Effects', 182),
#  ('Crash Dive ', 'Special Effects', 182),
#  ('The North Star ', 'Special Effects', 182),
#  ('So Proudly We Hail! ', 'Special Effects', 182),
#  ('Stand By for Action ', 'Special Effects', 182),
#  ('Action in the North Atlantic ', 'Writing (Original Motion Picture Story)', 182),
#  ('Destination Tokyo ', 'Writing (Original Motion Picture Story)', 182),
#  ('The Human Comedy ', 'Writing (Original Motion Picture Story)', 182),
#  ('The More the Merrier ', 'Writing (Original Motion Picture Story)', 182),
#  ('Shadow of a Doubt ', 'Writing (Original Motion Picture Story)', 182),
#  ('Air Force ', 'Writing (Original Screenplay)', 182),
#  ('In Which We Serve ', 'Writing (Original Screenplay)', 182),
#  ('The North Star ', 'Writing (Original Screenplay)', 182),
#  ("Princess O'Rourke ", 'Writing (Original Screenplay)', 182),
#  ('So Proudly We Hail! ', 'Writing (Original Screenplay)', 182),
#  ('Casablanca ', 'Writing (Screenplay)', 182),
#  ('Holy Matrimony ', 'Writing (Screenplay)', 182),
#  ('The More the Merrier ', 'Writing (Screenplay)', 182),
#  ('The Song of Bernadette ', 'Writing (Screenplay)', 182),
#  ('Watch on the Rhine ', 'Writing (Screenplay)', 182),
#  ('George Pal', 'Special Award', 182),
#  ('Hal B. Wallis', 'Irving G. Thalberg Memorial Award', 182),
#  ('Charles Boyer', 'Actor', 169),
#  ('Bing Crosby', 'Actor', 169),
#  ('Barry Fitzgerald', 'Actor', 169),
#  ('Cary Grant', 'Actor', 169),
#  ('Alexander Knox', 'Actor', 169),
#  ('Hume Cronyn', 'Actor in a Supporting Role', 169),
#  ('Barry Fitzgerald', 'Actor in a Supporting Role', 169),
#  ('Claude Rains', 'Actor in a Supporting Role', 169),
#  ('Clifton Webb', 'Actor in a Supporting Role', 169),
#  ('Monty Woolley', 'Actor in a Supporting Role', 169),
#  ('Ingrid Bergman', 'Actress', 169),
#  ('Claudette Colbert', 'Actress', 169),
#  ('Bette Davis', 'Actress', 169),
#  ('Greer Garson', 'Actress', 169),
#  ('Barbara Stanwyck', 'Actress', 169),
#  ('Ethel Barrymore', 'Actress in a Supporting Role', 169),
#  ('Jennifer Jones', 'Actress in a Supporting Role', 169),
#  ('Angela Lansbury', 'Actress in a Supporting Role', 169),
#  ('Aline MacMahon', 'Actress in a Supporting Role', 169),
#  ('Agnes Moorehead', 'Actress in a Supporting Role', 169),
#  ('Address Unknown ', 'Art Direction (Black and White)', 169),
#  ('The Adventures of Mark Twain ', 'Art Direction (Black and White)', 169),
#  ('Casanova Brown ', 'Art Direction (Black and White)', 169),
#  ('Gaslight ', 'Art Direction (Black and White)', 169),
#  ('Laura ', 'Art Direction (Black and White)', 169),
#  ('No Time for Love ', 'Art Direction (Black and White)', 169),
#  ('Since You Went Away ', 'Art Direction (Black and White)', 169),
#  ('Song of the Open Road', 'Art Direction (Black and White)', 169),
#  ('Step Lively ', 'Art Direction (Black and White)', 169),
#  ('The Climax ', 'Art Direction (Color)', 169),
#  ('Cover Girl ', 'Art Direction (Color)', 169),
#  ('The Desert Song ', 'Art Direction (Color)', 169),
#  ('Kismet ', 'Art Direction (Color)', 169),
#  ('Lady in the Dark ', 'Art Direction (Color)', 169),
#  ('The Princess and the Pirate ', 'Art Direction (Color)', 169),
#  ('Wilson ', 'Art Direction (Color)', 169),
#  ('Double Indemnity ', 'Cinematography (Black and White)', 169),
#  ('Dragon Seed ', 'Cinematography (Black and White)', 169),
#  ('Gaslight ', 'Cinematography (Black and White)', 169),
#  ('Going My Way ', 'Cinematography (Black and White)', 169),
#  ('Laura ', 'Cinematography (Black and White)', 169),
#  ('Lifeboat ', 'Cinematography (Black and White)', 169),
#  ('Since You Went Away ', 'Cinematography (Black and White)', 169),
#  ('Thirty Seconds over Tokyo ', 'Cinematography (Black and White)', 169),
#  ('The Uninvited ', 'Cinematography (Black and White)', 169),
#  ('The White Cliffs of Dover ', 'Cinematography (Black and White)', 169),
#  ('Cover Girl ', 'Cinematography (Color)', 169),
#  ('Home in Indiana ', 'Cinematography (Color)', 169),
#  ('Kismet ', 'Cinematography (Color)', 169),
#  ('Lady in the Dark ', 'Cinematography (Color)', 169),
#  ('Meet Me in St. Louis ', 'Cinematography (Color)', 169),
#  ('Wilson ', 'Cinematography (Color)', 169),
#  ('Double Indemnity ', 'Directing', 169),
#  ('Going My Way ', 'Directing', 169),
#  ('Laura ', 'Directing', 169),
#  ('Lifeboat ', 'Directing', 169),
#  ('Wilson ', 'Directing', 169),
#  ('The Fighting Lady ', 'Documentary (Feature)', 169),
#  ('Resisting Enemy Interrogation ', 'Documentary (Feature)', 169),
#  ('Arturo Toscanini ', 'Documentary (Short Subject)', 169),
#  ('New Americans ', 'Documentary (Short Subject)', 169),
#  ('With the Marines at Tarawa ', 'Documentary (Short Subject)', 169),
#  ('Going My Way ', 'Film Editing', 169),
#  ('Janie ', 'Film Editing', 169),
#  ('None but the Lonely Heart ', 'Film Editing', 169),
#  ('Since You Went Away ', 'Film Editing', 169),
#  ('Wilson ', 'Film Editing', 169),
#  ('Address Unknown ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('The Adventures of Mark Twain ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('The Bridge of San Luis Rey ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Casanova Brown ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Christmas Holiday ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Double Indemnity ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('The Fighting Seabees ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('The Hairy Ape ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('It Happened Tomorrow ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Jack London ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Kismet ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('None but the Lonely Heart ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('The Princess and the Pirate ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Since You Went Away ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Summer Storm ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Three Russian Girls ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ("Up in Mabel's Room ", 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Voice in the Wind ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Wilson ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Woman of the Town ', 'Music (Music Score of a Dramatic or Comedy Picture)', 169),
#  ('Brazil ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Cover Girl ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Higher and Higher ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Hollywood Canteen ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Irish Eyes Are Smiling ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Knickerbocker Holiday ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Lady in the Dark ', 'Music (Scoring of a Musical Picture)', 169),
#  ("Lady, Let's Dance ", 'Music (Scoring of a Musical Picture)', 169),
#  ('Meet Me in St. Louis ', 'Music (Scoring of a Musical Picture)', 169),
#  ('The Merry Monahans ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Minstrel Man ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Sensations of 1945 ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Song of the Open Road ', 'Music (Scoring of a Musical Picture)', 169),
#  ('Up in Arms ', 'Music (Scoring of a Musical Picture)', 169),
#  ('"""I Couldn\'t Sleep A Wink Last Night"" from Higher and Higher"', 'Music (Song)', 169),
#  ('"""I\'ll Walk Alone"" from Follow the Boys"', 'Music (Song)', 169),
#  ('"""I\'m Making Believe"" from Sweet and Lowdown"', 'Music (Song)', 169),
#  ('"""Long Ago And Far Away"" from Cover Girl"', 'Music (Song)', 169),
#  ('"""Now I Know"" from Up in Arms"', 'Music (Song)', 169),
#  ('"""Remember Me To Carolina"" from Minstrel Man"', 'Music (Song)', 169),
#  ('"""Rio De Janeiro"" from Brazil"', 'Music (Song)', 169),
#  ('"""Silver Shadows And Golden Dreams"" from Lady, Let\'s Dance"', 'Music (Song)', 169),
#  ('"""Sweet Dreams Sweetheart"" from Hollywood Canteen"', 'Music (Song)', 169),
#  ('"""Swinging On A Star"" from Going My Way"', 'Music (Song)', 169),
#  ('"""Too Much In Love"" from Song of the Open Road"', 'Music (Song)', 169),
#  ('"""The Trolley Song"" from Meet Me in St. Louis"', 'Music (Song)', 169),
#  ('Double Indemnity ', 'Best Motion Picture', 169),
#  ('Gaslight ', 'Best Motion Picture', 169),
#  ('Going My Way ', 'Best Motion Picture', 169),
#  ('Since You Went Away ', 'Best Motion Picture', 169),
#  ('Wilson ', 'Best Motion Picture', 169),
#  ('And to Think I Saw It on Mulberry Street ', 'Short Subject (Cartoon)', 169),
#  ('Dog, Cat and Canary ', 'Short Subject (Cartoon)', 169),
#  ('Fish Fry ', 'Short Subject (Cartoon)', 169),
#  ('How to Play Football ', 'Short Subject (Cartoon)', 169),
#  ('Mouse Trouble ', 'Short Subject (Cartoon)', 169),
#  ('My Boy Johnny ', 'Short Subject (Cartoon)', 169),
#  ('Swooner Crooner ', 'Short Subject (Cartoon)', 169),
#  ('Blue Grass Gentlemen ', 'Short Subject (One Reel)', 169),
#  ("Jammin' the Blues ", 'Short Subject (One Reel)', 169),
#  ('Movie Pests ', 'Short Subject (One Reel)', 169),
#  ("Screen Snapshots' 50th Anniversary of Motion Pictures ", 'Short Subject (One Reel)', 169),
#  ("Who's Who in Animal Land ", 'Short Subject (One Reel)', 169),
#  ('Bombalera ', 'Short Subject (Two Reel)', 169),
#  ("I Won't Play ", 'Short Subject (Two Reel)', 169),
#  ('Main Street Today ', 'Short Subject (Two Reel)', 169),
#  ('Brazil ', 'Sound Recording', 169),
#  ('Casanova Brown ', 'Sound Recording', 169),
#  ('Cover Girl ', 'Sound Recording', 169),
#  ('Double Indemnity ', 'Sound Recording', 169),
#  ("His Butler's Sister ", 'Sound Recording', 169),
#  ('Hollywood Canteen ', 'Sound Recording', 169),
#  ('It Happened Tomorrow ', 'Sound Recording', 169),
#  ('Kismet ', 'Sound Recording', 169),
#  ('Music in Manhattan ', 'Sound Recording', 169),
#  ('Voice in the Wind ', 'Sound Recording', 169),
#  ('Wilson ', 'Sound Recording', 169),
#  ('The Adventures of Mark Twain ', 'Special Effects', 169),
#  ('Days of Glory ', 'Special Effects', 169),
#  ('Secret Command ', 'Special Effects', 169),
#  ('Since You Went Away ', 'Special Effects', 169),
#  ('The Story of Dr. Wassell ', 'Special Effects', 169),
#  ('Thirty Seconds over Tokyo ', 'Special Effects', 169),
#  ('Wilson ', 'Special Effects', 169),
#  ('Going My Way ', 'Writing (Original Motion Picture Story)', 169),
#  ('A Guy Named Joe ', 'Writing (Original Motion Picture Story)', 169),
#  ('Lifeboat ', 'Writing (Original Motion Picture Story)', 169),
#  ('None Shall Escape ', 'Writing (Original Motion Picture Story)', 169),
#  ('The Sullivans ', 'Writing (Original Motion Picture Story)', 169),
#  ('Hail the Conquering Hero ', 'Writing (Original Screenplay)', 169),
#  ("The Miracle of Morgan's Creek ", 'Writing (Original Screenplay)', 169),
#  ('Two Girls and a Sailor ', 'Writing (Original Screenplay)', 169),
#  ('Wilson ', 'Writing (Original Screenplay)', 169),
#  ('Wing and a Prayer ', 'Writing (Original Screenplay)', 169),
#  ('Double Indemnity ', 'Writing (Screenplay)', 169),
#  ('Gaslight ', 'Writing (Screenplay)', 169),
#  ('Going My Way ', 'Writing (Screenplay)', 169),
#  ('Laura ', 'Writing (Screenplay)', 169),
#  ('Meet Me in St. Louis ', 'Writing (Screenplay)', 169),
#  ("Margaret O'Brien", 'Special Award', 169),
#  ('Bob Hope', 'Special Award', 169),
#  ('Darryl F. Zanuck', 'Irving G. Thalberg Memorial Award', 169),
#  ('Charles Chaplin', 'Actor', 160),
#  ('Henry Fonda', 'Actor', 160),
#  ('Raymond Massey', 'Actor', 160),
#  ('Laurence Olivier', 'Actor', 160),
#  ('James Stewart', 'Actor', 160),
#  ('Albert Basserman', 'Actor in a Supporting Role', 160),
#  ('Walter Brennan', 'Actor in a Supporting Role', 160),
#  ('William Gargan', 'Actor in a Supporting Role', 160),
#  ('Jack Oakie', 'Actor in a Supporting Role', 160),
#  ('James Stephenson', 'Actor in a Supporting Role', 160),
#  ('Bette Davis', 'Actress', 160),
#  ('Joan Fontaine', 'Actress', 160),
#  ('Katharine Hepburn', 'Actress', 160),
#  ('Ginger Rogers', 'Actress', 160),
#  ('Martha Scott', 'Actress', 160),
#  ('Judith Anderson', 'Actress in a Supporting Role', 160),
#  ('Jane Darwell', 'Actress in a Supporting Role', 160),
#  ('Ruth Hussey', 'Actress in a Supporting Role', 160),
#  ("Barbara O'Neil", 'Actress in a Supporting Role', 160),
#  ('Marjorie Rambeau', 'Actress in a Supporting Role', 160),
#  ('Arise, My Love ', 'Art Direction (Black and White)', 160),
#  ('Arizona ', 'Art Direction (Black and White)', 160),
#  ('The Boys from Syracuse ', 'Art Direction (Black and White)', 160),
#  ('The Dark Command ', 'Art Direction (Black and White)', 160),
#  ('Foreign Correspondent ', 'Art Direction (Black and White)', 160),
#  ('Lillian Russell ', 'Art Direction (Black and White)', 160),
#  ('My Favorite Wife ', 'Art Direction (Black and White)', 160),
#  ('My Son, My Son! ', 'Art Direction (Black and White)', 160),
#  ('Our Town ', 'Art Direction (Black and White)', 160),
#  ('Pride and Prejudice ', 'Art Direction (Black and White)', 160),
#  ('Rebecca ', 'Art Direction (Black and White)', 160),
#  ('The Sea Hawk ', 'Art Direction (Black and White)', 160),
#  ('The Westerner ', 'Art Direction (Black and White)', 160),
#  ('Bitter Sweet ', 'Art Direction (Color)', 160),
#  ('Down Argentine Way ', 'Art Direction (Color)', 160),
#  ('North West Mounted Police ', 'Art Direction (Color)', 160),
#  ('The Thief of Bagdad ', 'Art Direction (Color)', 160),
#  ('Abe Lincoln in Illinois ', 'Cinematography (Black and White)', 160),
#  ('All This, and Heaven Too ', 'Cinematography (Black and White)', 160),
#  ('Arise, My Love ', 'Cinematography (Black and White)', 160),
#  ('Boom Town ', 'Cinematography (Black and White)', 160),
#  ('Foreign Correspondent ', 'Cinematography (Black and White)', 160),
#  ('The Letter ', 'Cinematography (Black and White)', 160),
#  ('The Long Voyage Home ', 'Cinematography (Black and White)', 160),
#  ('Rebecca ', 'Cinematography (Black and White)', 160),
#  ('Spring Parade ', 'Cinematography (Black and White)', 160),
#  ('Waterloo Bridge ', 'Cinematography (Black and White)', 160),
#  ('Bitter Sweet ', 'Cinematography (Color)', 160),
#  ('The Blue Bird ', 'Cinematography (Color)', 160),
#  ('Down Argentine Way ', 'Cinematography (Color)', 160),
#  ('North West Mounted Police ', 'Cinematography (Color)', 160),
#  ('Northwest Passage ', 'Cinematography (Color)', 160),
#  ('The Thief of Bagdad ', 'Cinematography (Color)', 160),
#  ('The Grapes of Wrath ', 'Directing', 160),
#  ('Kitty Foyle ', 'Directing', 160),
#  ('The Letter ', 'Directing', 160),
#  ('The Philadelphia Story ', 'Directing', 160),
#  ('Rebecca ', 'Directing', 160),
#  ('The Grapes of Wrath ', 'Film Editing', 160),
#  ('The Letter ', 'Film Editing', 160),
#  ('The Long Voyage Home ', 'Film Editing', 160),
#  ('North West Mounted Police ', 'Film Editing', 160),
#  ('Rebecca ', 'Film Editing', 160),
#  ('Arizona ', 'Music (Original Score)', 160),
#  ('The Dark Command ', 'Music (Original Score)', 160),
#  ('The Fight for Life ', 'Music (Original Score)', 160),
#  ('The Great Dictator ', 'Music (Original Score)', 160),
#  ('The House of the Seven Gables ', 'Music (Original Score)', 160),
#  ('The Howards of Virginia ', 'Music (Original Score)', 160),
#  ('The Letter ', 'Music (Original Score)', 160),
#  ('The Long Voyage Home ', 'Music (Original Score)', 160),
#  ('The Mark of Zorro ', 'Music (Original Score)', 160),
#  ('My Favorite Wife ', 'Music (Original Score)', 160),
#  ('North West Mounted Police ', 'Music (Original Score)', 160),
#  ('One Million B.C. ', 'Music (Original Score)', 160),
#  ('Our Town ', 'Music (Original Score)', 160),
#  ('Pinocchio ', 'Music (Original Score)', 160),
#  ('Rebecca ', 'Music (Original Score)', 160),
#  ('The Thief of Bagdad ', 'Music (Original Score)', 160),
#  ('Waterloo Bridge ', 'Music (Original Score)', 160),
#  ('Arise, My Love ', 'Music (Scoring)', 160),
#  ('Hit Parade of 1941 ', 'Music (Scoring)', 160),
#  ('Irene ', 'Music (Scoring)', 160),
#  ('Our Town ', 'Music (Scoring)', 160),
#  ('The Sea Hawk ', 'Music (Scoring)', 160),
#  ('Second Chorus ', 'Music (Scoring)', 160),
#  ('Spring Parade ', 'Music (Scoring)', 160),
#  ('Strike Up the Band ', 'Music (Scoring)', 160),
#  ('Tin Pan Alley ', 'Music (Scoring)', 160),
#  ('"""Down Argentina Way"" from Down Argentine Way"', 'Music (Song)', 160),
#  ('"""I\'d Know You Anywhere"" from You\'ll Find Out"', 'Music (Song)', 160),
#  ('"""It\'s A Blue World"" from Music in My Heart"', 'Music (Song)', 160),
#  ('"""Love Of My Life"" from Second Chorus"', 'Music (Song)', 160),
#  ('"""Only Forever"" from Rhythm on the River"', 'Music (Song)', 160),
#  ('"""Our Love Affair"" from Strike Up the Band"', 'Music (Song)', 160),
#  ('"""Waltzing In The Clouds"" from Spring Parade"', 'Music (Song)', 160),
#  ('"""When You Wish Upon A Star"" from Pinocchio"', 'Music (Song)', 160),
#  ('"""Who Am I?"" from Hit Parade of 1941"', 'Music (Song)', 160),
#  ('All This, and Heaven Too ', 'Outstanding Production', 160),
#  ('Foreign Correspondent ', 'Outstanding Production', 160),
#  ('The Grapes of Wrath ', 'Outstanding Production', 160),
#  ('The Great Dictator ', 'Outstanding Production', 160),
#  ('Kitty Foyle ', 'Outstanding Production', 160),
#  ('The Letter ', 'Outstanding Production', 160),
#  ('The Long Voyage Home ', 'Outstanding Production', 160),
#  ('Our Town ', 'Outstanding Production', 160),
#  ('The Philadelphia Story ', 'Outstanding Production', 160),
#  ('Rebecca ', 'Outstanding Production', 160),
#  ('The Milky Way ', 'Short Subject (Cartoon)', 160),
#  ('Puss Gets the Boot ', 'Short Subject (Cartoon)', 160),
#  ('A Wild Hare ', 'Short Subject (Cartoon)', 160),
#  ('London Can Take It ', 'Short Subject (One Reel)', 160),
#  ('More about Nostradamus ', 'Short Subject (One Reel)', 160),
#  ("Quicker 'N a Wink ", 'Short Subject (One Reel)', 160),
#  ('Siege ', 'Short Subject (One Reel)', 160),
#  ('Eyes of the Navy ', 'Short Subject (Two Reel)', 160),
#  ('Service with the Colors ', 'Short Subject (Two Reel)', 160),
#  ('Teddy, the Rough Rider ', 'Short Subject (Two Reel)', 160),
#  ('Behind the News ', 'Sound Recording', 160),
#  ('Captain Caution ', 'Sound Recording', 160),
#  ('The Grapes of Wrath ', 'Sound Recording', 160),
#  ('The Howards of Virginia ', 'Sound Recording', 160),
#  ('Kitty Foyle ', 'Sound Recording', 160),
#  ('North West Mounted Police ', 'Sound Recording', 160),
#  ('Our Town ', 'Sound Recording', 160),
#  ('The Sea Hawk ', 'Sound Recording', 160),
#  ('Spring Parade ', 'Sound Recording', 160),
#  ('Strike Up the Band ', 'Sound Recording', 160),
#  ('Too Many Husbands ', 'Sound Recording', 160),
#  ('The Blue Bird ', 'Special Effects', 160),
#  ('Boom Town ', 'Special Effects', 160),
#  ('The Boys from Syracuse ', 'Special Effects', 160),
#  ('Dr. Cyclops ', 'Special Effects', 160),
#  ('Foreign Correspondent ', 'Special Effects', 160),
#  ('The Invisible Man Returns ', 'Special Effects', 160),
#  ('The Long Voyage Home ', 'Special Effects', 160),
#  ('One Million B.C. ', 'Special Effects', 160),
#  ('Rebecca ', 'Special Effects', 160),
#  ('The Sea Hawk ', 'Special Effects', 160),
#  ('Swiss Family Robinson ', 'Special Effects', 160),
#  ('The Thief of Bagdad ', 'Special Effects', 160),
#  ('Typhoon ', 'Special Effects', 160),
#  ('Women in War ', 'Special Effects', 160),
#  ('Angels over Broadway ', 'Writing (Original Screenplay)', 160),
#  ("Dr. Ehrlich's Magic Bullet ", 'Writing (Original Screenplay)', 160),
#  ('Foreign Correspondent ', 'Writing (Original Screenplay)', 160),
#  ('The Great Dictator ', 'Writing (Original Screenplay)', 160),
#  ('The Great McGinty ', 'Writing (Original Screenplay)', 160),
#  ('Arise, My Love ', 'Writing (Original Story)', 160),
#  ('Comrade X ', 'Writing (Original Story)', 160),
#  ('Edison, the Man ', 'Writing (Original Story)', 160),
#  ('My Favorite Wife ', 'Writing (Original Story)', 160),
#  ('The Westerner ', 'Writing (Original Story)', 160),
#  ('The Grapes of Wrath ', 'Writing (Screenplay)', 160),
#  ('Kitty Foyle ', 'Writing (Screenplay)', 160),
#  ('The Long Voyage Home ', 'Writing (Screenplay)', 160),
#  ('The Philadelphia Story ', 'Writing (Screenplay)', 160),
#  ('Rebecca ', 'Writing (Screenplay)', 160),
#  ('Bob Hope', 'Special Award', 160),
#  ('Colonel Nathan Levinson', 'Special Award', 160),
#  ('Bing Crosby', 'Actor', 160),
#  ('Gene Kelly', 'Actor', 160),
#  ('Ray Milland', 'Actor', 160),
#  ('Gregory Peck', 'Actor', 160),
#  ('Cornel Wilde', 'Actor', 160),
#  ('Michael Chekhov', 'Actor in a Supporting Role', 160),
#  ('John Dall', 'Actor in a Supporting Role', 160),
#  ('James Dunn', 'Actor in a Supporting Role', 160),
#  ('Robert Mitchum', 'Actor in a Supporting Role', 160),
#  ('J. Carrol Naish', 'Actor in a Supporting Role', 160),
#  ('Ingrid Bergman', 'Actress', 160),
#  ('Joan Crawford', 'Actress', 160),
#  ('Greer Garson', 'Actress', 160),
#  ('Jennifer Jones', 'Actress', 160),
#  ('Gene Tierney', 'Actress', 160),
#  ('Eve Arden', 'Actress in a Supporting Role', 160),
#  ('Ann Blyth', 'Actress in a Supporting Role', 160),
#  ('Angela Lansbury', 'Actress in a Supporting Role', 160),
#  ('Joan Lorring', 'Actress in a Supporting Role', 160),
#  ('Anne Revere', 'Actress in a Supporting Role', 160),
#  ('Blood on the Sun ', 'Art Direction (Black and White)', 160),
#  ('Experiment Perilous ', 'Art Direction (Black and White)', 160),
#  ('The Keys of the Kingdom ', 'Art Direction (Black and White)', 160),
#  ('Love Letters ', 'Art Direction (Black and White)', 160),
#  ('The Picture of Dorian Gray ', 'Art Direction (Black and White)', 160),
#  ("Frenchman's Creek ", 'Art Direction (Color)', 160),
#  ('Leave Her to Heaven ', 'Art Direction (Color)', 160),
#  ('National Velvet ', 'Art Direction (Color)', 160),
#  ('San Antonio ', 'Art Direction (Color)', 160),
#  ('A Thousand and One Nights ', 'Art Direction (Color)', 160),
#  ('The Keys of the Kingdom ', 'Cinematography (Black and White)', 160),
#  ('The Lost Weekend ', 'Cinematography (Black and White)', 160),
#  ('Mildred Pierce ', 'Cinematography (Black and White)', 160),
#  ('The Picture of Dorian Gray ', 'Cinematography (Black and White)', 160),
#  ('Spellbound ', 'Cinematography (Black and White)', 160),
#  ('Anchors Aweigh ', 'Cinematography (Color)', 160),
#  ('Leave Her to Heaven ', 'Cinematography (Color)', 160),
#  ('National Velvet ', 'Cinematography (Color)', 160),
#  ('A Song to Remember ', 'Cinematography (Color)', 160),
#  ('The Spanish Main ', 'Cinematography (Color)', 160),
#  ("The Bells of St. Mary's ", 'Directing', 160),
#  ('The Lost Weekend ', 'Directing', 160),
#  ('National Velvet ', 'Directing', 160),
#  ('The Southerner ', 'Directing', 160),
#  ('Spellbound ', 'Directing', 160),
#  ('The Last Bomb ', 'Documentary (Feature)', 160),
#  ('The True Glory ', 'Documentary (Feature)', 160),
#  ('Hitler Lives? ', 'Documentary (Short Subject)', 160),
#  ('Library of Congress ', 'Documentary (Short Subject)', 160),
#  ('To the Shores of Iwo Jima ', 'Documentary (Short Subject)', 160),
#  ("The Bells of St. Mary's ", 'Film Editing', 160),
#  ('The Lost Weekend ', 'Film Editing', 160),
#  ('National Velvet ', 'Film Editing', 160),
#  ('Objective, Burma! ', 'Film Editing', 160),
#  ('A Song to Remember ', 'Film Editing', 160),
#  ("The Bells of St. Mary's ", 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ("Brewster's Millions ", 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Captain Kidd ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Enchanted Cottage ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Flame of Barbary Coast ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('G. I. Honeymoon ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('G. I. Joe ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Guest in the House ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Guest Wife ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Keys of the Kingdom ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Lost Weekend ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Love Letters ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Man Who Walked Alone ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Objective, Burma! ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Paris--Underground ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('A Song to Remember ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Southerner ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Spellbound ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('This Love of Ours ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Valley of Decision ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('The Woman in the Window ', 'Music (Music Score of a Dramatic or Comedy Picture)', 160),
#  ('Anchors Aweigh ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Belle of the Yukon ', 'Music (Scoring of a Musical Picture)', 160),
#  ("Can't Help Singing ", 'Music (Scoring of a Musical Picture)', 160),
#  ('Hitchhike to Happiness ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Incendiary Blonde ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Rhapsody in Blue ', 'Music (Scoring of a Musical Picture)', 160),
#  ('State Fair ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Sunbonnet Sue ', 'Music (Scoring of a Musical Picture)', 160),
#  ('The Three Caballeros ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Tonight and Every Night ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Why Girls Leave Home ', 'Music (Scoring of a Musical Picture)', 160),
#  ('Wonder Man ', 'Music (Scoring of a Musical Picture)', 160),
#  ('"""Accentuate The Positive"" from Here Come the Waves"', 'Music (Song)', 160),
#  ('"""Anywhere"" from Tonight and Every Night"', 'Music (Song)', 160),
#  ('"""Aren\'t You Glad You\'re You?"" from The Bells of St. Mary\'s"', 'Music (Song)', 160),
#  ('"""The Cat And The Canary"" from Why Girls Leave Home"', 'Music (Song)', 160),
#  ('"""Endlessly"" from Earl Carroll Vanities"', 'Music (Song)', 160),
#  ('"""I Fall In Love Too Easily"" from Anchors Aweigh"', 'Music (Song)', 160),
#  ('"""I\'ll Buy That Dream"" from Sing Your Way Home"', 'Music (Song)', 160),
#  ('"""It Might As Well Be Spring"" from State Fair"', 'Music (Song)', 160),
#  ('"""Linda"" from G. I. Joe"', 'Music (Song)', 160),
#  ('"""Love Letters"" from Love Letters"', 'Music (Song)', 160),
#  ('"""More And More"" from Can\'t Help Singing"', 'Music (Song)', 160),
#  ('"""Sleighride In July"" from Belle of the Yukon"', 'Music (Song)', 160),
#  ('"""So In Love"" from Wonder Man"', 'Music (Song)', 160),
#  ('"""Some Sunday Morning"" from San Antonio"', 'Music (Song)', 160),
#  ('Anchors Aweigh ', 'Best Motion Picture', 160),
#  ("The Bells of St. Mary's ", 'Best Motion Picture', 160),
#  ('The Lost Weekend ', 'Best Motion Picture', 160),
#  ('Mildred Pierce ', 'Best Motion Picture', 160),
#  ('Spellbound ', 'Best Motion Picture', 160),
#  ("Donald's Crime ", 'Short Subject (Cartoon)', 160),
#  ('Jasper and the Beanstalk ', 'Short Subject (Cartoon)', 160),
#  ('Life with Feathers ', 'Short Subject (Cartoon)', 160),
#  ('Mighty Mouse in Gypsy Life ', 'Short Subject (Cartoon)', 160),
#  ('The Poet and Peasant ', 'Short Subject (Cartoon)', 160),
#  ('Quiet Please! ', 'Short Subject (Cartoon)', 160),
#  ('Rippling Romance ', 'Short Subject (Cartoon)', 160),
#  ('Along the Rainbow Trail ', 'Short Subject (One Reel)', 160),
#  ("Screen Snapshots' 25th Anniversary ", 'Short Subject (One Reel)', 160),
#  ('Stairway to Light ', 'Short Subject (One Reel)', 160),
#  ('Story of a Dog ', 'Short Subject (One Reel)', 160),
#  ('White Rhapsody ', 'Short Subject (One Reel)', 160),
#  ('Your National Gallery ', 'Short Subject (One Reel)', 160),
#  ...]

# %% [markdown]
# ### Question 13
#
# For all of the entries in the Oscars table before 1934, the year is stored differently than in all the subsequent years. For example, the year would be saved as “1932/1933” instead of just “1933” (the second indicated year).  Which of the following options would be the appropriate code to update this column to have the format of the year be consistent throughout the entire table (second indicated year only shown)?
#
#
# **Options:**
#
# - `UPDATE Oscars SET year = RIGHT(year, -4)`
# - `UPDATE Oscars SET year = SELECT substr(year, -4)`
# - `UPDATE Oscars SET year = substr(year, -4)`
# - `UPDATE Oscars year =  substr(year, 4)`

# %%
 `UPDATE Oscars SET year = substr(year, -4)`

# %% [markdown]
# ### Question 14
#
# DStv will be having a special week dedicated to the actor Alan Rickman. Which of the following queries would create a new _view_ that shows the titles, release dates, taglines, and overviews of all movies that Alan Rickman has played in?
#
#
#
# **Options:**
#
# - SELECT title, release_date, tagline, overview
# FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# AS VIEW Alan_Rickman_Movies
#
# - CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
#
#
# - CREATE NEW VIEW  Name  = Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'
#
# - VIEW Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'

# %%
# %%sql
#
# - CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'

# %% [markdown]
# ### Question 15
#
# Which of the statements about database normalisation are true?
#
# **Statements:**
#
# i) Database normalisation improves data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# ii) Database normalisation supports up to the Third Normal Form and removes all data anomalies.
#
# iii) Database normalisation removes inconsistencies that may cause the analysis of our data to be more complicated.
#
# iv) Database normalisation increases data redundancy, saves on storage space, and fulfils the requirement of records to be uniquely identified.
#
# **Options:**
#
#  - (i) and (ii)
#  - (i) and (iii)
#  - (ii) and (iv)
#  - (iii) and (iv)

# %%
(i) and (iii)
